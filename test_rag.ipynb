# %% [markdown]
# # StartupLens - Failed Startups RAG Pipeline Testing
# This notebook demonstrates the retrieval pipeline for failed startup ideas.

# %%
import os
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_groq import ChatGroq
from src.rag.retriever import get_failed_startups_info

print('Imports successful!')
# Out:
# Imports successful!

# %%
CHROMA_DB_DIR = os.path.join("data", "chroma")
db_exists = os.path.exists(CHROMA_DB_DIR)
print(f"ChromaDB exists at {CHROMA_DB_DIR}: {db_exists}")

if db_exists:
    embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
    vectorstore = Chroma(persist_directory=CHROMA_DB_DIR, embedding_function=embeddings)
    print(f"Total documents in Vector Store: {vectorstore._collection.count()}")
# Out:
# ChromaDB exists at data\chroma: True
# Total documents in Vector Store: 1224

# %%
query = "Fintech payments"
docs = vectorstore.as_retriever(search_kwargs={"k": 3}).invoke(query)
print(f"Retrieved {len(docs)} documents.")
for i, doc in enumerate(docs):
    print(f"\n--- Document {i+1} ---")
    print(doc.page_content[:200].replace('\n', ' | ') + "...")
# Out:
# Retrieved 3 documents.
#
# --- Document 1 ---
# Name: LendUp | Sector: Finance and Insurance | Years of Operation: 2012-2021 | What They Did: Loans for subprime borrowers | How Much They Raised: $350M | Why They Failed: Regulatory fines and OppLoans competit...
#
# --- Document 2 ---
# Name: Pay By Touch | Sector: Finance and Insurance | Years of Operation: 2002-2007 | What They Did: Biometric payments | How Much They Raised: $300M (est.) | Why They Failed: Lost to PayPal and tech issues | Take...
#
# --- Document 3 ---
# Name: Bitpass | Sector: Finance and Insurance | Years of Operation: 2002-2008 | What They Did: Micropayments platform | How Much They Raised: $2M | Why They Failed: Lost to PayPal and low adoption | Takeaway: Mic...

# %%
from dotenv import load_dotenv
load_dotenv()
groq_key = os.environ.get("GROQ_API_KEY")

if not groq_key:
    print("GROQ_API_KEY is missing from .env, generation will return an error message.")

res = get_failed_startups_info("Fintech payments", groq_key)

import json
print(json.dumps(res, indent=2))
# Out:
# GROQ_API_KEY is missing from .env, generation will return an error message.
# {
#   "startups": [],
#   "summary": "Error analyzing failed startups data. Please check logs or your API key."
# }
